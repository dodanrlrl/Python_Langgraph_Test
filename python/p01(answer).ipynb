# %% [markdown]
# # Problem Set 01

# %% [markdown]
# ## 점수 평균과 합격 판별
#
# 학생 점수 리스트가 있다.
#
# ```py
# scores = [80, 75, 90, 60, 100]
# ```
# 평균을 구하시오.
# 평균이 80 이상이면 "합격" 아니면 "불합격" 출력

# %%
scores = [80, 75, 90, 60, 100]

# 내장 함수 사용
# avg = sum(scores) / len(scores)

total = 0
for score in scores:
    total += score

avg = total / len(scores)

print(avg)

if avg >= 80:
    print('합격')
else:
    print('불합격')

# %% [markdown]
# ## 최대값 찾기
#
# 숫자 리스트가 있다.
# ```
# numbers = [3, 7, 2, 9, 5]
# ```
# 가장 큰 값을 찾아 출력하시오.
#
# Tip: `max()` 없이 직접 비교해보기

# %%
numbers = [30, 7, 120, 9, 5]

# max(numbers)

# 최댓값 찾기 전의 최댓값 = 첫번째
max_val = numbers[0]

for num in numbers:
    # 비교해서 크면
    if num > max_val:
        # 최댓값 교체
        max_val = num

print(max_val)

# %% [markdown]
# ## 짝수만 저장하기
# ```
# numbers = [1, 2, 3, 4, 5, 6, 7, 8]
# ```
# 짝수만 새로운 리스트에 담아서 출력하시오.

# %%
numbers = [1, 2, 3, 4, 5, 6, 7, 8]
# 짝수 저장용 새로운 리스트
evens = []

# 하나씩 돌면서
for num in numbers:
    # 짝수면
    if num % 2 == 0:
        # 새 리스트에 추가
        evens.append(num)

print(evens)

# %%
# List Comprehension
[num for num in numbers if num % 2 == 0]

# %% [markdown]
# ## 이름 존재 여부 확인
# ```
# names = ["철수", "영희", "민수", "지영"]
# ```
# 변수 target 에 저장된 이름이 리스트 안에 있으면
# "존재합니다" 아니면 "없습니다" 출력
#
# TIP: `in` 연산자 없이 풀기

# %%
while True:
    print('무한루프..?')
    break

# %%
target = '영희'
names = ["철수", "영희", "민수", "지영"]

# 초기 세팅
result = False   # 있으면 True, 없으면 False

# 있나 없나 검사
for name in names:
    if target == name:
        result = True
        break  # 현재 돌고있는 반복문을 종료

if result == True:
    print('존재합니다')
else:
    print('없습니다.')

# %% [markdown]
# ## 리스트 안 딕셔너리 평균 구하기
# ```
# students = [
#     {"name": "철수", "score": 80},
#     {"name": "영희", "score": 90},
#     {"name": "민수", "score": 70}
# ]
# ```
# 전체 평균 점수 구하기
# 평균 이상인 학생 이름 출력

# %%
students = [
    {"name": "철수", "score": 80},
    {"name": "영희", "score": 90},
    {"name": "민수", "score": 70}
]

# dict 잘 접근해서 데이터 뽑기

# %% [markdown]
# ## 비밀번호 검사기
#
# `password = "abc123"`
#
# 조건:
#
# 1. 길이가 8자 이상이고
# 1. 숫자가 포함되어 있으면 "사용 가능"
# 1. 아니면 "사용 불가"
#
# 출력하시오.
#
# (힌트: `len()`, `in` 사용)

# %%
password = "abcd1sdf"

len(password)

char = '9'
char in '0123456789'

# '2'.isdigit()

# %% [markdown]
# ## 장바구니 총 금액 계산
# ```py
# cart = [
#     {"item": "노트북", "price": 900000, "qty": 1},
#     {"item": "마우스", "price": 20000, "qty": 2},
#     {"item": "마우스", "price": 30000, "qty": 2},
#     {"item": "마우스", "price": 10000, "qty": 2},
# ]
# ```
# 총 결제 금액 계산
# 100만원 이상이면 "고액 구매자" 출력

# %%
cart = [
    {"item": "노트북", "price": 900000, "qty": 1},
    {"item": "마우스", "price": 20000, "qty": 2},
    {"item": "타블렛", "price": 30000, "qty": 2},
    {"item": "이어폰", "price": 10000, "qty": 2},
]

for item in cart:
    print(item['price'])

# %% [markdown]
# ## 등급 매기기
#
# 점수 리스트:
# ```py
# scores = [95, 82, 67, 74, 88]
# ```
# 각 점수에 대해
#
# - 90 이상 -- 'A'
# - 80 이상 -- 'B'
# - 70 이상 -- 'C'
# - 그 외 -- 'D'
#
# 등급 리스트를 새로 만들어 출력하시오.

# %%
scores = [95, 82, 67, 74, 88]

# %% [markdown]
# ---
#
# ## 난이도 Up

# %% [markdown]
# ## 숫자 분석기
#
# 다음 리스트가 주어져 있다.
# ```
# numbers = [12, 7, 25, 4, 18, 31, 10, 9, 42, 15]
# ```
# 반복문과 조건문을 사용하여 다음을 구하시오.
#
# - 짝수의 개수
# - 홀수의 개수
# - 10 이상인 숫자의 합
# - 가장 큰 숫자
#
# 최종 결과가 다음과 같이 나오도록 하시오.
# ```
# 짝수 개수: 6
# 홀수 개수: 4
# 10 이상인 숫자의 합: 153
# 가장 큰 숫자: 42
# ```
# 조건: `max()`, `sum()` 사용 금지

# %%
numbers = [12, 7, 25, 4, 18, 31, 10, 9, 42, 15]

even_qty = 0
odd_qty = 0
total = 0
max_number = 0

#홀짝 갯수 구하기
for num in numbers :
  # 홀짝 갯수
  if num % 2 == 0:
    even_qty += 1
  else:
    odd_qty += 1
    
  # 10이상 숫자 합
  if num >= 10 :
      total += num
  # 가장 큰 숫자
  if num > max_number :
      max_number = num

print("짝수 개수:", even_qty)
print("홀수 개수:", odd_qty)
print("10이상인 숫자의 합:", total)
print("가장 큰 숫자:", max_number)

# %% [markdown]
# ## 숫자 등급 분류하기
#
# 다음 숫자 리스트가 주어져 있다.
# ```
# numbers = [95, 72, 88, 61, 45, 100, 77, 53, 82, 39]
# ```
# 반복문과 조건문을 사용하여 각 숫자를 다음 기준으로 분류하시오.
#
# - 90 이상 -- "A"
# - 80 이상 -- "B"
# -70 이상 -- "C"
# - 60 이상 -- "D"
# - 60 미만 -- "F"
#
# 그리고 각 등급에 해당하는 숫자의 개수도 구하시오.
#
# 예상 출력:
# ```
# 95 -- A
# 72 -- C
# 88 -- B
# 61 -- D
# 45 -- F
# 100 -- A
# 77 -- C
# 53 -- F
# 82 -- B
# 39 -- F
#
# A: 2개
# B: 2개
# C: 2개
# D: 1개
# F: 3개
# ```

# %%
numbers = [95, 72, 88, 61, 45, 100, 77, 53, 82, 39]
grades = []
A_num = 0
B_num = 0
C_num = 0
D_num = 0
F_num = 0

for num in numbers:
  if num >= 90:
    grades.append('A')
    A_num +=1
    print(num,"--A")
  elif num >= 80:
    grades.append('B')
    B_num +=1
    print(num, "--B")
  elif num >= 70:
    grades.append('C')
    C_num +=1
    print(num, "--C")
  elif num >= 60:
    grades.append('D')
    D_num +=1
    print(num, "--D")
  else:
    grades.append('F')
    F_num +=1
    print(num, "--F")

print('\n')
print('A:',A_num,'개')
print('B:',B_num,'개')
print('C:',C_num,'개')
print('D:',D_num,'개')
print('F:',F_num,'개')

# %% [markdown]
# ## 편의점 매출 분석
#
# 편의점에서 판매된 상품 데이터가 다음과 같이 주어져 있다.
# ```
# sales = [
#     {"name": "삼각김밥", "price": 1500, "quantity": 12},
#     {"name": "라면", "price": 1200, "quantity": 8},
#     {"name": "콜라", "price": 1800, "quantity": 5},
#     {"name": "샌드위치", "price": 3500, "quantity": 3},
#     {"name": "커피", "price": 2500, "quantity": 10}
# ]
# ```
# 각 상품의 매출액 = 가격 × 판매수량이라고 한다.
#
# 반복문과 조건문을 사용하여 다음을 출력하시오.
#
# - 각 상품의 매출액
# - 전체 매출액
# - 매출액이 20,000원 이상인 상품의 이름
# - 가장 많이 팔린 상품의 이름
#
# 예상 출력:
# ```
# 삼각김밥: 18000원
# 라면: 9600원
# 콜라: 9000원
# 샌드위치: 10500원
# 커피: 25000원
#
# 전체 매출액: 72100원
#
# 매출액 20000원 이상:
# 커피
#
# 가장 많이 팔린 상품: 삼각김밥
# ```

# %%
sales = [
    {"name": "삼각김밥", "price": 1500, "quantity": 12},
    {"name": "라면", "price": 1200, "quantity": 8},
    {"name": "콜라", "price": 1800, "quantity": 5},
    {"name": "샌드위치", "price": 3500, "quantity": 3},
    {"name": "커피", "price": 2500, "quantity": 10}
]
total_sales = 0
mores = []
best_product = ""
quantity = 0

for sale in sales:
  
  total_price = sale["price"]*sale["quantity"]
  # 상품별 매출
  print(f"{sale["name"]}: {total_price}원")
  total_sales += total_price
  # 매출 2만원 이상 상품
  if total_price >= 20000:
    mores.append(sale["name"])
  # 가장 많이 팔린 상품
  if sale["quantity"] > quantity:
    quantity = sale["quantity"]
    best_product = sale["name"]


 


print("\n")
print(f"전체 매출액: {total}원")
print("\n")
print("매출액 20000원 이상:")
print(f"{mores}")
print("\n")
print(f"가장 많이 팔린 상품: {best_product}")
# Out:
# 삼각김밥: 18000원
# 라면: 9600원
# 콜라: 9000원
# 샌드위치: 10500원
# 커피: 25000원
#
#
# 전체 매출액: 72100원
#
#
# 매출액 20000원 이상:
# ['커피']
#
#
# 가장 많이 팔린 상품: 삼각김밥
